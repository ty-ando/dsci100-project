# %% [markdown]
# Ty Ando DSCI-100 Project Planning Stage

# %% [markdown]
# Firstly, I will load the necessary library into the notebook. These libraries will allow us to perform several operations on the dataset we are investigating, such as creating plots and tidying data.

# %%
library(tidyverse)
library(repr)
library(tidymodels)

# %%
players_data <- read_csv("data/players.csv")
sessions_data <- read_csv("data/sessions.csv")
players_data
sessions_data

# %% [markdown]
# (1) Data Description:
# Provide a full descriptive summary of the dataset, including information such as the number of observations, summary statistics (report values to 2 decimal places), number of variables, name and type of variables, what the variables mean, any issues you see in the data, any other potential issues related to things you cannot directly see, how the data were collected, etc. Make sure to use bullet point lists or tables to summarize the variables in an easy-to-understand format.
#
# Note that the selected dataset(s) will probably contain more variables than you need. In fact, exploring how the different variables in the dataset affect your model may be a crucial part of the project. You need to summarize the full data regardless of which variables you may choose to use later on.

# %% [markdown]
# Above, I have loaded the necessary libraries and the data sets into this notebook. From the data sets printed above, we can notice that both contain lots of data (the second much more than the first). The first dataset represents the players on the server. The data set includes information on their experience level, if they are subscribed, their hashed email, number of played hours, first name, gender, and age, where each row represents a separate person.
#
# The second data set represents a list of individual play sessions by each player. The dataset includes information regarding their hashed email, the time they started that particular session, and the time they ended that same session.
